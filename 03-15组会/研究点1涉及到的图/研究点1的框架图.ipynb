# %%
import pandas as pd
import cv2
import os
from PIL import Image
import os
import random
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import pyplot as plt
# 设置全局字体大小为12
plt.rcParams['font.size'] = 16
# 设置全局字体加粗
# plt.rcParams['font.weight'] = 'bold'
# 设置全局字体为SimSun和Times New Roman
plt.rcParams['font.family'] = ['SimHei','SimSun']
plt.rcParams['figure.dpi'] = 500

# %%
root = "fig/"

'''画出一行5个图，每个图是来自这个分类'''
img = []
for i in range(5):
    img.append(Image.open(r'D:\Desktop\Iov-with-FL\03-15组会\研究点1涉及到的图\fig\图片{}.png'.format(i+1)))

# %%
# plt.imshow(img[0])
# plt.axis('off')

# # plt.subplot(1, 5, 2)
# plt.imshow(img[1])
# plt.axis('off')

# #     plt.title("RPM Spoofing")
# # plt.subplot(1, 5, 3)
# plt.imshow(img[2])
# plt.axis('off')

# #     plt.title("Gear Spoofing")
# # plt.subplot(1, 5, 4)
# plt.imshow(img[3])
# plt.axis('off')

# #     plt.title("DoS Attack")
# # plt.subplot(1, 5, 5)
# plt.imshow(img[4])
# #     plt.title("Fuzzy Attack")
# plt.axis('off')
# plt.show()

# %%
plt.figure(figsize=(22, 4))
plt.subplot(1, 5, 1)
plt.imshow(img[0])
plt.title("R 正常")
plt.subplot(1, 5, 2)
plt.imshow(img[1])
plt.title("RPM 欺骗")
plt.subplot(1, 5, 3)
plt.imshow(img[2])
plt.title("Gear 欺骗")
plt.subplot(1, 5, 4)
plt.imshow(img[3])
plt.title("DoS 攻击")
plt.subplot(1, 5, 5)
plt.imshow(img[4])
plt.title("Fuzzy 攻击")
plt.show()
