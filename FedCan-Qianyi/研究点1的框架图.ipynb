# %%
from dataset_create import *

# %%
def getfileName(directory_path):
    files = os.listdir(directory_path)
    random_number = random.randint(1, 800)
    return files[random_number]
# def class_figure(root):
'''画出一行5个图，每个图是来自这个分类'''
img = []
for i in range(5):
    filedir = '{}{}'.format(root, "train/{}/".format(i))
    img.append(Image.open('{}{}'.format(filedir, getfileName(filedir))))

# plt.figure(figsize=(12, 4))
# plt.subplot(1, 5, 1)
plt.imshow(img[0])
#     plt.title("Normal")
plt.axis('off')
# Out:
# (-0.5, 8.5, 8.5, -0.5)

# %%
# plt.subplot(1, 5, 2)
plt.imshow(img[1])
plt.axis('off')
# Out:
# (-0.5, 8.5, 8.5, -0.5)

# %%
#     plt.title("RPM Spoofing")
# plt.subplot(1, 5, 3)
plt.imshow(img[2])
plt.axis('off')
# Out:
# (-0.5, 8.5, 8.5, -0.5)

# %%
#     plt.title("Gear Spoofing")
# plt.subplot(1, 5, 4)
plt.imshow(img[3])
plt.axis('off')
# Out:
# (-0.5, 8.5, 8.5, -0.5)

# %%
#     plt.title("DoS Attack")
# plt.subplot(1, 5, 5)
plt.imshow(img[4])
#     plt.title("Fuzzy Attack")
plt.axis('off')
plt.show()

# %%
root = "/home/raoxy/data/carhacking_our/car_11/"
class_figure(root)
